# %%
"""
All background sky scan without prior -> high/low rates

04_get_versatile_background_allsky_scan_high_low_rate.py
"""
# Out:
# '\nAll background sky scan without prior -> high/low rates\n\n04_get_versatile_background_allsky_scan_high_low_rate.py\n'

# %%
import sys
import os
import glob
import numpy as np
import pandas as pd
sys.path.append('../../../')
from greco_grb.scripts import SETTING
paths = SETTING.PATH()
print(paths)
LOCATION = paths.LOCATION
USER = paths.USER
ICDATA_DIR = paths.ICDATA_DIR
DATA_DIR = paths.DATA_DIR
ANA_DIR = paths.ANA_DIR

from greco_grb.scripts.utils import *
# Out:
# #### Working at GT ####
#
# LOCATION: 	 GT
# USER: 	 cchen641
# ICDATA_DIR: 	 /storage/home/hhive1/cchen641/data/icecube/data/analyses/online_GRECO/candidate-002-p10
# DATA_DIR: 	 /storage/home/hhive1/cchen641/data/icecube/data/greco_grb/data
# ANA_DIR: 	 /storage/home/hhive1/cchen641/data/icecube/data/greco_grb/data/csky_output

# %%
### create arguments arrays ---> input.txt
# 0: grb_name
# 1: batchNtrials
# 2: batchIndex
# 3: tw_in_second
# 4: ncpu
# 5: mode
# 6: outfilename

# %% [markdown]
# # Check 1 out of 2

# %%
####### Check before running ########
mode = "production"           # production or testing
script_path = '/scratch/cjchen/submit/04.sub'
## [::-1] reverse order
tws_in_second    = [   10,   25,   50,  100,  250,  500][::-1]   
njob_start       = [    0,    0,    0,  100,  100,  100][::-1]
njob_end         = [  100,  100,  100,  100,  100,  100][::-1]
batchsizes       = [ 1000, 1000, 1000, 1000, 1000, 1000][::-1]
grb_name         = "GRB180423A"    # an example grb used to create controled seeds
ncpu             = 4               # multi-core may result in out-of-memory
#######################################

# %%
contents = ""
for idx, (tw_in_second, batchNtrials) in enumerate(zip(tws_in_second, batchsizes)):
    for batchIndex in range(njob_start[idx], njob_end[idx]):
        outfilename = "{}_batchSize{}_batchIndex{}_tw{}.npz".format(grb_name, 
                                                                    batchNtrials, 
                                                                    batchIndex, 
                                                                    tw_in_second)
        if os.path.exists(ANA_DIR+"/allsky_scan/no_prior_versatile/high/tw{}/{}".format(tw_in_second, outfilename)) \
        and os.path.exists(ANA_DIR+"/allsky_scan/no_prior_versatile/low/tw{}/{}".format(tw_in_second, outfilename)):
            print("The npz file already exists.")
            print(outfilename)
            continue
            
        contents += "{}\t".format(grb_name)
        contents += "{}\t".format(batchNtrials)
        contents += "{}\t".format(batchIndex)
        contents += "{}\t".format(tw_in_second)
        contents += "{}\t".format(ncpu)
        contents += "{}\t".format(mode)
        contents += "{}\n".format(outfilename)

with open("04.txt", 'w') as writer:
    writer.write(contents)

# %%
print(contents)
# Out:
# GRB180423A	1000	0	50	4	production	GRB180423A_batchSize1000_batchIndex0_tw50.npz
# GRB180423A	1000	1	50	4	production	GRB180423A_batchSize1000_batchIndex1_tw50.npz
# GRB180423A	1000	2	50	4	production	GRB180423A_batchSize1000_batchIndex2_tw50.npz
# GRB180423A	1000	3	50	4	production	GRB180423A_batchSize1000_batchIndex3_tw50.npz
# GRB180423A	1000	4	50	4	production	GRB180423A_batchSize1000_batchIndex4_tw50.npz
# GRB180423A	1000	5	50	4	production	GRB180423A_batchSize1000_batchIndex5_tw50.npz
# GRB180423A	1000	6	50	4	production	GRB180423A_batchSize1000_batchIndex6_tw50.npz
# GRB180423A	1000	7	50	4	production	GRB180423A_batchSize1000_batchIndex7_tw50.npz
# GRB180423A	1000	8	50	4	production	GRB180423A_batchSize1000_batchIndex8_tw50.npz
# GRB180423A	1000	9	50	4	production	GRB180423A_batchSize1000_batchIndex9_tw50.npz
# GRB180423A	1000	10	50	4	production	GRB180423A_batchSize1000_batchIndex10_tw50.npz
# GRB180423A	1000	11	50	4	production	GRB180423A_batchSize1000_batchIndex11_tw50.npz
# GRB180423A	1000	12	50	4	production	GRB180423A_batchSize1000_batchIndex12_tw50.npz
# GRB180423A	1000	13	50	4	production	GRB180423A_batchSize1000_batchIndex13_tw50.npz
# GRB180423A	1000	14	50	4	production	GRB180423A_batchSize1000_batchIndex14_tw50.npz
# GRB180423A	1000	15	50	4	production	GRB180423A_batchSize1000_batchIndex15_tw50.npz
# GRB180423A	1000	16	50	4	production	GRB180423A_batchSize1000_batchIndex16_tw50.npz
# GRB180423A	1000	17	50	4	production	GRB180423A_batchSize1000_batchIndex17_tw50.npz
# GRB180423A	1000	18	50	4	production	GRB180423A_batchSize1000_batchIndex18_tw50.npz
# GRB180423A	1000	19	50	4	production	GRB180423A_batchSize1000_batchIndex19_tw50.npz
# GRB180423A	1000	20	50	4	production	GRB180423A_batchSize1000_batchIndex20_tw50.npz
# GRB180423A	1000	21	50	4	production	GRB180423A_batchSize1000_batchIndex21_tw50.npz
# GRB180423A	1000	22	50	4	production	GRB180423A_batchSize1000_batchIndex22_tw50.npz
# GRB180423A	1000	23	50	4	production	GRB180423A_batchSize1000_batchIndex23_tw50.npz
# GRB180423A	1000	24	50	4	production	GRB180423A_batchSize1000_batchIndex24_tw50.npz
# GRB180423A	1000	25	50	4	production	GRB180423A_batchSize1000_batchIndex25_tw50.npz
# GRB180423A	1000	26	50	4	production	GRB180423A_batchSize1000_batchIndex26_tw50.npz
# GRB180423A	1000	27	50	4	production	GRB180423A_batchSize1000_batchIndex27_tw50.npz
# GRB180423A	1000	28	50	4	production	GRB180423A_batchSize1000_batchIndex28_tw50.npz
# GRB180423A	1000	29	50	4	production	GRB180423A_batchSize1000_batchIndex29_tw50.npz
# GRB180423A	1000	30	50	4	production	GRB180423A_batchSize1000_batchIndex30_tw50.npz
# GRB180423A	1000	31	50	4	production	GRB180423A_batchSize1000_batchIndex31_tw50.npz
# GRB180423A	1000	32	50	4	production	GRB180423A_batchSize1000_batchIndex32_tw50.npz
# GRB180423A	1000	33	50	4	production	GRB180423A_batchSize1000_batchIndex33_tw50.npz
# GRB180423A	1000	34	50	4	production	GRB180423A_batchSize1000_batchIndex34_tw50.npz
# GRB180423A	1000	35	50	4	production	GRB180423A_batchSize1000_batchIndex35_tw50.npz
# GRB180423A	1000	36	50	4	production	GRB180423A_batchSize1000_batchIndex36_tw50.npz
# GRB180423A	1000	37	50	4	production	GRB180423A_batchSize1000_batchIndex37_tw50.npz
# GRB180423A	1000	38	50	4	production	GRB180423A_batchSize1000_batchIndex38_tw50.npz
# GRB180423A	1000	39	50	4	production	GRB180423A_batchSize1000_batchIndex39_tw50.npz
# GRB180423A	1000	40	50	4	production	GRB180423A_batchSize1000_batchIndex40_tw50.npz
# GRB180423A	1000	41	50	4	production	GRB180423A_batchSize1000_batchIndex41_tw50.npz
# GRB180423A	1000	42	50	4	production	GRB180423A_batchSize1000_batchIndex42_tw50.npz
# GRB180423A	1000	43	50	4	production	GRB180423A_batchSize1000_batchIndex43_tw50.npz
# GRB180423A	1000	44	50	4	production	GRB180423A_batchSize1000_batchIndex44_tw50.npz
# GRB180423A	1000	45	50	4	production	GRB180423A_batchSize1000_batchIndex45_tw50.npz
# GRB180423A	1000	46	50	4	production	GRB180423A_batchSize1000_batchIndex46_tw50.npz
# GRB180423A	1000	47	50	4	production	GRB180423A_batchSize1000_batchIndex47_tw50.npz
# GRB180423A	1000	48	50	4	production	GRB180423A_batchSize1000_batchIndex48_tw50.npz
# GRB180423A	1000	49	50	4	production	GRB180423A_batchSize1000_batchIndex49_tw50.npz
# GRB180423A	1000	50	50	4	production	GRB180423A_batchSize1000_batchIndex50_tw50.npz
# GRB180423A	1000	51	50	4	production	GRB180423A_batchSize1000_batchIndex51_tw50.npz
# GRB180423A	1000	52	50	4	production	GRB180423A_batchSize1000_batchIndex52_tw50.npz
# GRB180423A	1000	53	50	4	production	GRB180423A_batchSize1000_batchIndex53_tw50.npz
# GRB180423A	1000	54	50	4	production	GRB180423A_batchSize1000_batchIndex54_tw50.npz
# GRB180423A	1000	55	50	4	production	GRB180423A_batchSize1000_batchIndex55_tw50.npz
# GRB180423A	1000	56	50	4	production	GRB180423A_batchSize1000_batchIndex56_tw50.npz
# GRB180423A	1000	57	50	4	production	GRB180423A_batchSize1000_batchIndex57_tw50.npz
# GRB180423A	1000	58	50	4	production	GRB180423A_batchSize1000_batchIndex58_tw50.npz
# GRB180423A	1000	59	50	4	production	GRB180423A_batchSize1000_batchIndex59_tw50.npz
# GRB180423A	1000	60	50	4	production	GRB180423A_batchSize1000_batchIndex60_tw50.npz
# GRB180423A	1000	61	50	4	production	GRB180423A_batchSize1000_batchIndex61_tw50.npz
# GRB180423A	1000	62	50	4	production	GRB180423A_batchSize1000_batchIndex62_tw50.npz
# GRB180423A	1000	63	50	4	production	GRB180423A_batchSize1000_batchIndex63_tw50.npz
# GRB180423A	1000	64	50	4	production	GRB180423A_batchSize1000_batchIndex64_tw50.npz
# GRB180423A	1000	65	50	4	production	GRB180423A_batchSize1000_batchIndex65_tw50.npz
# GRB180423A	1000	66	50	4	production	GRB180423A_batchSize1000_batchIndex66_tw50.npz
# GRB180423A	1000	67	50	4	production	GRB180423A_batchSize1000_batchIndex67_tw50.npz
# GRB180423A	1000	68	50	4	production	GRB180423A_batchSize1000_batchIndex68_tw50.npz
# GRB180423A	1000	69	50	4	production	GRB180423A_batchSize1000_batchIndex69_tw50.npz
# GRB180423A	1000	70	50	4	production	GRB180423A_batchSize1000_batchIndex70_tw50.npz
# GRB180423A	1000	71	50	4	production	GRB180423A_batchSize1000_batchIndex71_tw50.npz
# GRB180423A	1000	72	50	4	production	GRB180423A_batchSize1000_batchIndex72_tw50.npz
# GRB180423A	1000	73	50	4	production	GRB180423A_batchSize1000_batchIndex73_tw50.npz
# GRB180423A	1000	74	50	4	production	GRB180423A_batchSize1000_batchIndex74_tw50.npz
# GRB180423A	1000	75	50	4	production	GRB180423A_batchSize1000_batchIndex75_tw50.npz
# GRB180423A	1000	76	50	4	production	GRB180423A_batchSize1000_batchIndex76_tw50.npz
# GRB180423A	1000	77	50	4	production	GRB180423A_batchSize1000_batchIndex77_tw50.npz
# GRB180423A	1000	78	50	4	production	GRB180423A_batchSize1000_batchIndex78_tw50.npz
# GRB180423A	1000	79	50	4	production	GRB180423A_batchSize1000_batchIndex79_tw50.npz
# GRB180423A	1000	80	50	4	production	GRB180423A_batchSize1000_batchIndex80_tw50.npz
# GRB180423A	1000	81	50	4	production	GRB180423A_batchSize1000_batchIndex81_tw50.npz
# GRB180423A	1000	82	50	4	production	GRB180423A_batchSize1000_batchIndex82_tw50.npz
# GRB180423A	1000	83	50	4	production	GRB180423A_batchSize1000_batchIndex83_tw50.npz
# GRB180423A	1000	84	50	4	production	GRB180423A_batchSize1000_batchIndex84_tw50.npz
# GRB180423A	1000	85	50	4	production	GRB180423A_batchSize1000_batchIndex85_tw50.npz
# GRB180423A	1000	86	50	4	production	GRB180423A_batchSize1000_batchIndex86_tw50.npz
# GRB180423A	1000	87	50	4	production	GRB180423A_batchSize1000_batchIndex87_tw50.npz
# GRB180423A	1000	88	50	4	production	GRB180423A_batchSize1000_batchIndex88_tw50.npz
# GRB180423A	1000	89	50	4	production	GRB180423A_batchSize1000_batchIndex89_tw50.npz
# GRB180423A	1000	90	50	4	production	GRB180423A_batchSize1000_batchIndex90_tw50.npz
# GRB180423A	1000	91	50	4	production	GRB180423A_batchSize1000_batchIndex91_tw50.npz
# GRB180423A	1000	92	50	4	production	GRB180423A_batchSize1000_batchIndex92_tw50.npz
# GRB180423A	1000	93	50	4	production	GRB180423A_batchSize1000_batchIndex93_tw50.npz
# GRB180423A	1000	94	50	4	production	GRB180423A_batchSize1000_batchIndex94_tw50.npz
# GRB180423A	1000	95	50	4	production	GRB180423A_batchSize1000_batchIndex95_tw50.npz
# GRB180423A	1000	96	50	4	production	GRB180423A_batchSize1000_batchIndex96_tw50.npz
# GRB180423A	1000	97	50	4	production	GRB180423A_batchSize1000_batchIndex97_tw50.npz
# GRB180423A	1000	98	50	4	production	GRB180423A_batchSize1000_batchIndex98_tw50.npz
# GRB180423A	1000	99	50	4	production	GRB180423A_batchSize1000_batchIndex99_tw50.npz
# GRB180423A	1000	0	25	4	production	GRB180423A_batchSize1000_batchIndex0_tw25.npz
# GRB180423A	1000	1	25	4	production	GRB180423A_batchSize1000_batchIndex1_tw25.npz
# GRB180423A	1000	2	25	4	production	GRB180423A_batchSize1000_batchIndex2_tw25.npz
# GRB180423A	1000	3	25	4	production	GRB180423A_batchSize1000_batchIndex3_tw25.npz
# GRB180423A	1000	4	25	4	production	GRB180423A_batchSize1000_batchIndex4_tw25.npz
# GRB180423A	1000	5	25	4	production	GRB180423A_batchSize1000_batchIndex5_tw25.npz
# GRB180423A	1000	6	25	4	production	GRB180423A_batchSize1000_batchIndex6_tw25.npz
# GRB180423A	1000	7	25	4	production	GRB180423A_batchSize1000_batchIndex7_tw25.npz
# GRB180423A	1000	8	25	4	production	GRB180423A_batchSize1000_batchIndex8_tw25.npz
# GRB180423A	1000	9	25	4	production	GRB180423A_batchSize1000_batchIndex9_tw25.npz
# GRB180423A	1000	10	25	4	production	GRB180423A_batchSize1000_batchIndex10_tw25.npz
# GRB180423A	1000	11	25	4	production	GRB180423A_batchSize1000_batchIndex11_tw25.npz
# GRB180423A	1000	12	25	4	production	GRB180423A_batchSize1000_batchIndex12_tw25.npz
# GRB180423A	1000	13	25	4	production	GRB180423A_batchSize1000_batchIndex13_tw25.npz
# GRB180423A	1000	14	25	4	production	GRB180423A_batchSize1000_batchIndex14_tw25.npz
# GRB180423A	1000	15	25	4	production	GRB180423A_batchSize1000_batchIndex15_tw25.npz
# GRB180423A	1000	16	25	4	production	GRB180423A_batchSize1000_batchIndex16_tw25.npz
# GRB180423A	1000	17	25	4	production	GRB180423A_batchSize1000_batchIndex17_tw25.npz
# GRB180423A	1000	18	25	4	production	GRB180423A_batchSize1000_batchIndex18_tw25.npz
# GRB180423A	1000	19	25	4	production	GRB180423A_batchSize1000_batchIndex19_tw25.npz
# GRB180423A	1000	20	25	4	production	GRB180423A_batchSize1000_batchIndex20_tw25.npz
# GRB180423A	1000	21	25	4	production	GRB180423A_batchSize1000_batchIndex21_tw25.npz
# GRB180423A	1000	22	25	4	production	GRB180423A_batchSize1000_batchIndex22_tw25.npz
# GRB180423A	1000	23	25	4	production	GRB180423A_batchSize1000_batchIndex23_tw25.npz
# GRB180423A	1000	24	25	4	production	GRB180423A_batchSize1000_batchIndex24_tw25.npz
# GRB180423A	1000	25	25	4	production	GRB180423A_batchSize1000_batchIndex25_tw25.npz
# GRB180423A	1000	26	25	4	production	GRB180423A_batchSize1000_batchIndex26_tw25.npz
# GRB180423A	1000	27	25	4	production	GRB180423A_batchSize1000_batchIndex27_tw25.npz
# GRB180423A	1000	28	25	4	production	GRB180423A_batchSize1000_batchIndex28_tw25.npz
# GRB180423A	1000	29	25	4	production	GRB180423A_batchSize1000_batchIndex29_tw25.npz
# GRB180423A	1000	30	25	4	production	GRB180423A_batchSize1000_batchIndex30_tw25.npz
# GRB180423A	1000	31	25	4	production	GRB180423A_batchSize1000_batchIndex31_tw25.npz
# GRB180423A	1000	32	25	4	production	GRB180423A_batchSize1000_batchIndex32_tw25.npz
# GRB180423A	1000	33	25	4	production	GRB180423A_batchSize1000_batchIndex33_tw25.npz
# GRB180423A	1000	34	25	4	production	GRB180423A_batchSize1000_batchIndex34_tw25.npz
# GRB180423A	1000	35	25	4	production	GRB180423A_batchSize1000_batchIndex35_tw25.npz
# GRB180423A	1000	36	25	4	production	GRB180423A_batchSize1000_batchIndex36_tw25.npz
# GRB180423A	1000	37	25	4	production	GRB180423A_batchSize1000_batchIndex37_tw25.npz
# GRB180423A	1000	38	25	4	production	GRB180423A_batchSize1000_batchIndex38_tw25.npz
# GRB180423A	1000	39	25	4	production	GRB180423A_batchSize1000_batchIndex39_tw25.npz
# GRB180423A	1000	40	25	4	production	GRB180423A_batchSize1000_batchIndex40_tw25.npz
# GRB180423A	1000	41	25	4	production	GRB180423A_batchSize1000_batchIndex41_tw25.npz
# GRB180423A	1000	42	25	4	production	GRB180423A_batchSize1000_batchIndex42_tw25.npz
# GRB180423A	1000	43	25	4	production	GRB180423A_batchSize1000_batchIndex43_tw25.npz
# GRB180423A	1000	44	25	4	production	GRB180423A_batchSize1000_batchIndex44_tw25.npz
# GRB180423A	1000	45	25	4	production	GRB180423A_batchSize1000_batchIndex45_tw25.npz
# GRB180423A	1000	46	25	4	production	GRB180423A_batchSize1000_batchIndex46_tw25.npz
# GRB180423A	1000	47	25	4	production	GRB180423A_batchSize1000_batchIndex47_tw25.npz
# GRB180423A	1000	48	25	4	production	GRB180423A_batchSize1000_batchIndex48_tw25.npz
# GRB180423A	1000	49	25	4	production	GRB180423A_batchSize1000_batchIndex49_tw25.npz
# GRB180423A	1000	50	25	4	production	GRB180423A_batchSize1000_batchIndex50_tw25.npz
# GRB180423A	1000	51	25	4	production	GRB180423A_batchSize1000_batchIndex51_tw25.npz
# GRB180423A	1000	52	25	4	production	GRB180423A_batchSize1000_batchIndex52_tw25.npz
# GRB180423A	1000	53	25	4	production	GRB180423A_batchSize1000_batchIndex53_tw25.npz
# GRB180423A	1000	54	25	4	production	GRB180423A_batchSize1000_batchIndex54_tw25.npz
# GRB180423A	1000	55	25	4	production	GRB180423A_batchSize1000_batchIndex55_tw25.npz
# GRB180423A	1000	56	25	4	production	GRB180423A_batchSize1000_batchIndex56_tw25.npz
# GRB180423A	1000	57	25	4	production	GRB180423A_batchSize1000_batchIndex57_tw25.npz
# GRB180423A	1000	58	25	4	production	GRB180423A_batchSize1000_batchIndex58_tw25.npz
# GRB180423A	1000	59	25	4	production	GRB180423A_batchSize1000_batchIndex59_tw25.npz
# GRB180423A	1000	60	25	4	production	GRB180423A_batchSize1000_batchIndex60_tw25.npz
# GRB180423A	1000	61	25	4	production	GRB180423A_batchSize1000_batchIndex61_tw25.npz
# GRB180423A	1000	62	25	4	production	GRB180423A_batchSize1000_batchIndex62_tw25.npz
# GRB180423A	1000	63	25	4	production	GRB180423A_batchSize1000_batchIndex63_tw25.npz
# GRB180423A	1000	64	25	4	production	GRB180423A_batchSize1000_batchIndex64_tw25.npz
# GRB180423A	1000	65	25	4	production	GRB180423A_batchSize1000_batchIndex65_tw25.npz
# GRB180423A	1000	66	25	4	production	GRB180423A_batchSize1000_batchIndex66_tw25.npz
# GRB180423A	1000	67	25	4	production	GRB180423A_batchSize1000_batchIndex67_tw25.npz
# GRB180423A	1000	68	25	4	production	GRB180423A_batchSize1000_batchIndex68_tw25.npz
# GRB180423A	1000	69	25	4	production	GRB180423A_batchSize1000_batchIndex69_tw25.npz
# GRB180423A	1000	70	25	4	production	GRB180423A_batchSize1000_batchIndex70_tw25.npz
# GRB180423A	1000	71	25	4	production	GRB180423A_batchSize1000_batchIndex71_tw25.npz
# GRB180423A	1000	72	25	4	production	GRB180423A_batchSize1000_batchIndex72_tw25.npz
# GRB180423A	1000	73	25	4	production	GRB180423A_batchSize1000_batchIndex73_tw25.npz
# GRB180423A	1000	74	25	4	production	GRB180423A_batchSize1000_batchIndex74_tw25.npz
# GRB180423A	1000	75	25	4	production	GRB180423A_batchSize1000_batchIndex75_tw25.npz
# GRB180423A	1000	76	25	4	production	GRB180423A_batchSize1000_batchIndex76_tw25.npz
# GRB180423A	1000	77	25	4	production	GRB180423A_batchSize1000_batchIndex77_tw25.npz
# GRB180423A	1000	78	25	4	production	GRB180423A_batchSize1000_batchIndex78_tw25.npz
# GRB180423A	1000	79	25	4	production	GRB180423A_batchSize1000_batchIndex79_tw25.npz
# GRB180423A	1000	80	25	4	production	GRB180423A_batchSize1000_batchIndex80_tw25.npz
# GRB180423A	1000	81	25	4	production	GRB180423A_batchSize1000_batchIndex81_tw25.npz
# GRB180423A	1000	82	25	4	production	GRB180423A_batchSize1000_batchIndex82_tw25.npz
# GRB180423A	1000	83	25	4	production	GRB180423A_batchSize1000_batchIndex83_tw25.npz
# GRB180423A	1000	84	25	4	production	GRB180423A_batchSize1000_batchIndex84_tw25.npz
# GRB180423A	1000	85	25	4	production	GRB180423A_batchSize1000_batchIndex85_tw25.npz
# GRB180423A	1000	86	25	4	production	GRB180423A_batchSize1000_batchIndex86_tw25.npz
# GRB180423A	1000	87	25	4	production	GRB180423A_batchSize1000_batchIndex87_tw25.npz
# GRB180423A	1000	88	25	4	production	GRB180423A_batchSize1000_batchIndex88_tw25.npz
# GRB180423A	1000	89	25	4	production	GRB180423A_batchSize1000_batchIndex89_tw25.npz
# GRB180423A	1000	90	25	4	production	GRB180423A_batchSize1000_batchIndex90_tw25.npz
# GRB180423A	1000	91	25	4	production	GRB180423A_batchSize1000_batchIndex91_tw25.npz
# GRB180423A	1000	92	25	4	production	GRB180423A_batchSize1000_batchIndex92_tw25.npz
# GRB180423A	1000	93	25	4	production	GRB180423A_batchSize1000_batchIndex93_tw25.npz
# GRB180423A	1000	94	25	4	production	GRB180423A_batchSize1000_batchIndex94_tw25.npz
# GRB180423A	1000	95	25	4	production	GRB180423A_batchSize1000_batchIndex95_tw25.npz
# GRB180423A	1000	96	25	4	production	GRB180423A_batchSize1000_batchIndex96_tw25.npz
# GRB180423A	1000	97	25	4	production	GRB180423A_batchSize1000_batchIndex97_tw25.npz
# GRB180423A	1000	98	25	4	production	GRB180423A_batchSize1000_batchIndex98_tw25.npz
# GRB180423A	1000	99	25	4	production	GRB180423A_batchSize1000_batchIndex99_tw25.npz
# GRB180423A	1000	0	10	4	production	GRB180423A_batchSize1000_batchIndex0_tw10.npz
# GRB180423A	1000	1	10	4	production	GRB180423A_batchSize1000_batchIndex1_tw10.npz
# GRB180423A	1000	2	10	4	production	GRB180423A_batchSize1000_batchIndex2_tw10.npz
# GRB180423A	1000	3	10	4	production	GRB180423A_batchSize1000_batchIndex3_tw10.npz
# GRB180423A	1000	4	10	4	production	GRB180423A_batchSize1000_batchIndex4_tw10.npz
# GRB180423A	1000	5	10	4	production	GRB180423A_batchSize1000_batchIndex5_tw10.npz
# GRB180423A	1000	6	10	4	production	GRB180423A_batchSize1000_batchIndex6_tw10.npz
# GRB180423A	1000	7	10	4	production	GRB180423A_batchSize1000_batchIndex7_tw10.npz
# GRB180423A	1000	8	10	4	production	GRB180423A_batchSize1000_batchIndex8_tw10.npz
# GRB180423A	1000	9	10	4	production	GRB180423A_batchSize1000_batchIndex9_tw10.npz
# GRB180423A	1000	10	10	4	production	GRB180423A_batchSize1000_batchIndex10_tw10.npz
# GRB180423A	1000	11	10	4	production	GRB180423A_batchSize1000_batchIndex11_tw10.npz
# GRB180423A	1000	12	10	4	production	GRB180423A_batchSize1000_batchIndex12_tw10.npz
# GRB180423A	1000	13	10	4	production	GRB180423A_batchSize1000_batchIndex13_tw10.npz
# GRB180423A	1000	14	10	4	production	GRB180423A_batchSize1000_batchIndex14_tw10.npz
# GRB180423A	1000	15	10	4	production	GRB180423A_batchSize1000_batchIndex15_tw10.npz
# GRB180423A	1000	16	10	4	production	GRB180423A_batchSize1000_batchIndex16_tw10.npz
# GRB180423A	1000	17	10	4	production	GRB180423A_batchSize1000_batchIndex17_tw10.npz
# GRB180423A	1000	18	10	4	production	GRB180423A_batchSize1000_batchIndex18_tw10.npz
# GRB180423A	1000	19	10	4	production	GRB180423A_batchSize1000_batchIndex19_tw10.npz
# GRB180423A	1000	20	10	4	production	GRB180423A_batchSize1000_batchIndex20_tw10.npz
# GRB180423A	1000	21	10	4	production	GRB180423A_batchSize1000_batchIndex21_tw10.npz
# GRB180423A	1000	22	10	4	production	GRB180423A_batchSize1000_batchIndex22_tw10.npz
# GRB180423A	1000	23	10	4	production	GRB180423A_batchSize1000_batchIndex23_tw10.npz
# GRB180423A	1000	24	10	4	production	GRB180423A_batchSize1000_batchIndex24_tw10.npz
# GRB180423A	1000	25	10	4	production	GRB180423A_batchSize1000_batchIndex25_tw10.npz
# GRB180423A	1000	26	10	4	production	GRB180423A_batchSize1000_batchIndex26_tw10.npz
# GRB180423A	1000	27	10	4	production	GRB180423A_batchSize1000_batchIndex27_tw10.npz
# GRB180423A	1000	28	10	4	production	GRB180423A_batchSize1000_batchIndex28_tw10.npz
# GRB180423A	1000	29	10	4	production	GRB180423A_batchSize1000_batchIndex29_tw10.npz
# GRB180423A	1000	30	10	4	production	GRB180423A_batchSize1000_batchIndex30_tw10.npz
# GRB180423A	1000	31	10	4	production	GRB180423A_batchSize1000_batchIndex31_tw10.npz
# GRB180423A	1000	32	10	4	production	GRB180423A_batchSize1000_batchIndex32_tw10.npz
# GRB180423A	1000	33	10	4	production	GRB180423A_batchSize1000_batchIndex33_tw10.npz
# GRB180423A	1000	34	10	4	production	GRB180423A_batchSize1000_batchIndex34_tw10.npz
# GRB180423A	1000	35	10	4	production	GRB180423A_batchSize1000_batchIndex35_tw10.npz
# GRB180423A	1000	36	10	4	production	GRB180423A_batchSize1000_batchIndex36_tw10.npz
# GRB180423A	1000	37	10	4	production	GRB180423A_batchSize1000_batchIndex37_tw10.npz
# GRB180423A	1000	38	10	4	production	GRB180423A_batchSize1000_batchIndex38_tw10.npz
# GRB180423A	1000	39	10	4	production	GRB180423A_batchSize1000_batchIndex39_tw10.npz
# GRB180423A	1000	40	10	4	production	GRB180423A_batchSize1000_batchIndex40_tw10.npz
# GRB180423A	1000	41	10	4	production	GRB180423A_batchSize1000_batchIndex41_tw10.npz
# GRB180423A	1000	42	10	4	production	GRB180423A_batchSize1000_batchIndex42_tw10.npz
# GRB180423A	1000	43	10	4	production	GRB180423A_batchSize1000_batchIndex43_tw10.npz
# GRB180423A	1000	44	10	4	production	GRB180423A_batchSize1000_batchIndex44_tw10.npz
# GRB180423A	1000	45	10	4	production	GRB180423A_batchSize1000_batchIndex45_tw10.npz
# GRB180423A	1000	46	10	4	production	GRB180423A_batchSize1000_batchIndex46_tw10.npz
# GRB180423A	1000	47	10	4	production	GRB180423A_batchSize1000_batchIndex47_tw10.npz
# GRB180423A	1000	48	10	4	production	GRB180423A_batchSize1000_batchIndex48_tw10.npz
# GRB180423A	1000	49	10	4	production	GRB180423A_batchSize1000_batchIndex49_tw10.npz
# GRB180423A	1000	50	10	4	production	GRB180423A_batchSize1000_batchIndex50_tw10.npz
# GRB180423A	1000	51	10	4	production	GRB180423A_batchSize1000_batchIndex51_tw10.npz
# GRB180423A	1000	52	10	4	production	GRB180423A_batchSize1000_batchIndex52_tw10.npz
# GRB180423A	1000	53	10	4	production	GRB180423A_batchSize1000_batchIndex53_tw10.npz
# GRB180423A	1000	54	10	4	production	GRB180423A_batchSize1000_batchIndex54_tw10.npz
# GRB180423A	1000	55	10	4	production	GRB180423A_batchSize1000_batchIndex55_tw10.npz
# GRB180423A	1000	56	10	4	production	GRB180423A_batchSize1000_batchIndex56_tw10.npz
# GRB180423A	1000	57	10	4	production	GRB180423A_batchSize1000_batchIndex57_tw10.npz
# GRB180423A	1000	58	10	4	production	GRB180423A_batchSize1000_batchIndex58_tw10.npz
# GRB180423A	1000	59	10	4	production	GRB180423A_batchSize1000_batchIndex59_tw10.npz
# GRB180423A	1000	60	10	4	production	GRB180423A_batchSize1000_batchIndex60_tw10.npz
# GRB180423A	1000	61	10	4	production	GRB180423A_batchSize1000_batchIndex61_tw10.npz
# GRB180423A	1000	62	10	4	production	GRB180423A_batchSize1000_batchIndex62_tw10.npz
# GRB180423A	1000	63	10	4	production	GRB180423A_batchSize1000_batchIndex63_tw10.npz
# GRB180423A	1000	64	10	4	production	GRB180423A_batchSize1000_batchIndex64_tw10.npz
# GRB180423A	1000	65	10	4	production	GRB180423A_batchSize1000_batchIndex65_tw10.npz
# GRB180423A	1000	66	10	4	production	GRB180423A_batchSize1000_batchIndex66_tw10.npz
# GRB180423A	1000	67	10	4	production	GRB180423A_batchSize1000_batchIndex67_tw10.npz
# GRB180423A	1000	68	10	4	production	GRB180423A_batchSize1000_batchIndex68_tw10.npz
# GRB180423A	1000	69	10	4	production	GRB180423A_batchSize1000_batchIndex69_tw10.npz
# GRB180423A	1000	70	10	4	production	GRB180423A_batchSize1000_batchIndex70_tw10.npz
# GRB180423A	1000	71	10	4	production	GRB180423A_batchSize1000_batchIndex71_tw10.npz
# GRB180423A	1000	72	10	4	production	GRB180423A_batchSize1000_batchIndex72_tw10.npz
# GRB180423A	1000	73	10	4	production	GRB180423A_batchSize1000_batchIndex73_tw10.npz
# GRB180423A	1000	74	10	4	production	GRB180423A_batchSize1000_batchIndex74_tw10.npz
# GRB180423A	1000	75	10	4	production	GRB180423A_batchSize1000_batchIndex75_tw10.npz
# GRB180423A	1000	76	10	4	production	GRB180423A_batchSize1000_batchIndex76_tw10.npz
# GRB180423A	1000	77	10	4	production	GRB180423A_batchSize1000_batchIndex77_tw10.npz
# GRB180423A	1000	78	10	4	production	GRB180423A_batchSize1000_batchIndex78_tw10.npz
# GRB180423A	1000	79	10	4	production	GRB180423A_batchSize1000_batchIndex79_tw10.npz
# GRB180423A	1000	80	10	4	production	GRB180423A_batchSize1000_batchIndex80_tw10.npz
# GRB180423A	1000	81	10	4	production	GRB180423A_batchSize1000_batchIndex81_tw10.npz
# GRB180423A	1000	82	10	4	production	GRB180423A_batchSize1000_batchIndex82_tw10.npz
# GRB180423A	1000	83	10	4	production	GRB180423A_batchSize1000_batchIndex83_tw10.npz
# GRB180423A	1000	84	10	4	production	GRB180423A_batchSize1000_batchIndex84_tw10.npz
# GRB180423A	1000	85	10	4	production	GRB180423A_batchSize1000_batchIndex85_tw10.npz
# GRB180423A	1000	86	10	4	production	GRB180423A_batchSize1000_batchIndex86_tw10.npz
# GRB180423A	1000	87	10	4	production	GRB180423A_batchSize1000_batchIndex87_tw10.npz
# GRB180423A	1000	88	10	4	production	GRB180423A_batchSize1000_batchIndex88_tw10.npz
# GRB180423A	1000	89	10	4	production	GRB180423A_batchSize1000_batchIndex89_tw10.npz
# GRB180423A	1000	90	10	4	production	GRB180423A_batchSize1000_batchIndex90_tw10.npz
# GRB180423A	1000	91	10	4	production	GRB180423A_batchSize1000_batchIndex91_tw10.npz
# GRB180423A	1000	92	10	4	production	GRB180423A_batchSize1000_batchIndex92_tw10.npz
# GRB180423A	1000	93	10	4	production	GRB180423A_batchSize1000_batchIndex93_tw10.npz
# GRB180423A	1000	94	10	4	production	GRB180423A_batchSize1000_batchIndex94_tw10.npz
# GRB180423A	1000	95	10	4	production	GRB180423A_batchSize1000_batchIndex95_tw10.npz
# GRB180423A	1000	96	10	4	production	GRB180423A_batchSize1000_batchIndex96_tw10.npz
# GRB180423A	1000	97	10	4	production	GRB180423A_batchSize1000_batchIndex97_tw10.npz
# GRB180423A	1000	98	10	4	production	GRB180423A_batchSize1000_batchIndex98_tw10.npz
# GRB180423A	1000	99	10	4	production	GRB180423A_batchSize1000_batchIndex99_tw10.npz

# %%
print("Total number of jobs: {}\n".format(contents.count('\n')))
# Out:
# Total number of jobs: 300

# %%
### create pbs file ---> 04.pbs

# %% [markdown]
# # Check 2 out of 2

# %%
nameofjob  = "04"
ntotal     = 300             # copy from the above 2nd cell "Total number of jobs: xxx"
inputtxt   = "04.txt"      # copy from the above 3rd cell
outdir     = ensure_dir("/storage/home/hhive1/cchen641/scratch/icecube/job_pbs_out/out")
walltimehr = 60           # in Hour: 1 cpu min / trial (x2 for redundancy) < 120 hrs

# %%
contents = ""
contents += "#PBS -N {}\n".format(nameofjob)
contents += "#PBS -l nodes=1:ppn={}\n".format(ncpu)           # number of nodes and cores per node required
contents += "#PBS -l pmem=4gb\n"                             # memory per core
contents += "#PBS -l walltime={}:00:00\n".format(walltimehr)  # dd:hh:mm:ss
contents += "#PBS -q hive\n"
contents += "#PBS -j oe\n"
contents += "#PBS -o {}\n".format(outdir+"/04.out")
contents += "#PBS -t 1-{}%400".format(ntotal)
contents += "\n"
contents += "cd /storage/home/hhive1/cchen641/icecube/greco_grb/scripts\n"
contents += "icpy3\n" 
# Get Paramters from input.txt file using $PBS_ARRAYID as the line number 
contents += 'params=`sed -n "${{PBS_ARRAYID}} p" {}`\n'.format("hive_sub/"+inputtxt)    # outer single quote to preserve inner double quotes
contents += "paramsArray=($params)\n"
contents += "arg0=${paramsArray[0]}\n"
contents += "arg1=${paramsArray[1]}\n"
contents += "arg2=${paramsArray[2]}\n"
contents += "arg3=${paramsArray[3]}\n"
contents += "arg4=${paramsArray[4]}\n"
contents += "arg5=${paramsArray[5]}\n"
contents += "arg6=${paramsArray[6]}\n"
contents += "python 04_get_versatile_background_allsky_scan_high_low_rate.py "
contents += "--grb_name $arg0 "
contents += "--batchNtrials $arg1 "
contents += "--batchIndex $arg2 "
contents += "--tw_in_second $arg3 "
contents += "--ncpu $arg4 "
contents += "--mode $arg5 "
contents += "--outfilename $arg6 "
print(contents)
with open("04.pbs", 'w') as writer:
    writer.write(contents)
# Out:
# #PBS -N 04
# #PBS -l nodes=1:ppn=4
# #PBS -l pmem=4gb
# #PBS -l walltime=60:00:00
# #PBS -q hive
# #PBS -j oe
# #PBS -o /storage/home/hhive1/cchen641/scratch/icecube/job_pbs_out/out/04.out
# #PBS -t 1-300%400
# cd /storage/home/hhive1/cchen641/icecube/greco_grb/scripts
# icpy3
# params=`sed -n "${PBS_ARRAYID} p" hive_sub/04.txt`
# paramsArray=($params)
# arg0=${paramsArray[0]}
# arg1=${paramsArray[1]}
# arg2=${paramsArray[2]}
# arg3=${paramsArray[3]}
# arg4=${paramsArray[4]}
# arg5=${paramsArray[5]}
# arg6=${paramsArray[6]}
# python 04_get_versatile_background_allsky_scan_high_low_rate.py --grb_name $arg0 --batchNtrials $arg1 --batchIndex $arg2 --tw_in_second $arg3 --ncpu $arg4 --mode $arg5 --outfilename $arg6
